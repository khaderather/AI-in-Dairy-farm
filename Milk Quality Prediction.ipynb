# %% [markdown]
# # Simple ML modelling for the prediction of Milk Quality

# %%
import numpy as np 
import pandas as pd 
df = pd.read_csv('milknew.csv')
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Printing shapes, data types
df.shape,df.dtypes,df.head()
# Out:
# ((1059, 8),
#  pH            float64
#  Temprature      int64
#  Taste           int64
#  Odor            int64
#  Fat             int64
#  Turbidity       int64
#  Colour          int64
#  Grade          object
#  dtype: object,
#      pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
#  0  6.6          35      1     0     1          0     254    high
#  1  6.6          36      0     1     0          1     253    high
#  2  8.5          70      1     1     1          1     246     low
#  3  9.5          34      1     1     0          1     255     low
#  4  6.6          37      0     0     0          0     255  medium)

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Checking for null values
df.isnull().sum()
# Out:
# pH            0
# Temprature    0
# Taste         0
# Odor          0
# Fat           0
# Turbidity     0
# Colour        0
# Grade         0
# dtype: int64

# %%
#Unique values
df.nunique()
# Out:
# pH            16
# Temprature    17
# Taste          2
# Odor           2
# Fat            2
# Turbidity      2
# Colour         9
# Grade          3
# dtype: int64

# %%
features = [i for i in df.columns]
features
# Out:
# ['pH', 'Temprature', 'Taste', 'Odor', 'Fat ', 'Turbidity', 'Colour', 'Grade']

# %% [markdown]
# ## Analysis of pH feature

# %%
def show_countplot(df,feature,hue=None):
    plt.figure(figsize=(15,8))
    ax=sns.countplot(data=df,x=feature,hue=hue)
    ax.set_title(feature + '  Vs. ' + 'Target')
    for p in ax.patches:
        text = str(round(p.get_height()/len(df)*100,2))+'%'
        ax.text(p.get_x(),p.get_height(),text)
    plt.show()
    
def show_pieplot(df,feature):
    plt.figure(figsize=(15,8))
    counts = df[feature].value_counts()
    values = counts.values
    keys = counts.index
    color= sns.color_palette('dark')
    plt.pie(x=values,labels=keys,colors=color,autopct='%.0f%%')
    plt.title('Pie chart for '+feature)
    plt.show()

# %%
show_countplot(df,'pH',hue='Grade')
show_pieplot(df,'pH')
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#Good Quality in pH range 6.4 to 6.8
#6.5 ph shown highest HIGH quality & 6.4 being lowest

# %% [markdown]
# ## Analysis of Taste feature

# %%
show_countplot(df,'Taste',hue='Grade')
show_pieplot(df,'Taste')

# %%
#Taste does not show any remarkable relation with Grade

# %% [markdown]
# ## Analysis of Temprature feature

# %%
show_countplot(df,'Temprature',hue='Grade')
show_pieplot(df,'Temprature')
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#Temperature at 45 have more data points and it is the optimal for the High grade milk
#Above 45 the Grade of milk is low

# %% [markdown]
# ## Analysis of Odor feature

# %%
show_countplot(df,'Odor',hue='Grade')
show_pieplot(df,'Odor')

# %%
#With Odor in the milk, it is likely to be very good or very bad.
#Without Odor the milk Grade is medium

# %% [markdown]
# ## Analysis of Turbidity Feature

# %%
show_countplot(df,'Turbidity',hue='Grade')
show_pieplot(df,'Turbidity')

# %%
#No relation with respect to High Grade milk

# %% [markdown]
# ## Analysis of Colour Feature

# %%
show_countplot(df,'Colour',hue='Grade')
show_pieplot(df,'Colour')
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#No relation with color
#255 shares most of the data points upto 59%

# %% [markdown]
# ## Analysis of Fat feature

# %%
show_countplot(df,'Fat ',hue='Grade')
show_pieplot(df,'Fat ')

# %%
#Milk with no fat is most likely to be Low grade or Medium
#Milk with fat is most likely to be High grade

# %%
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder,LabelBinarizer
le = LabelEncoder()
target = le.fit_transform(df.Grade)
map_dict = dict(zip(target,df.Grade))
df.Grade = target

# %% [markdown]
# ### Finding Correlation

# %%
plt.figure(figsize=(15,7))
data = df.corr()
sns.heatmap(data,annot=True,fmt='.1f',linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
#Odor,Fat,Turbudity,Colour & Taste Are important to Classify grade
#pH and Temperature show less covariance

# %% [markdown]
# ## ML Model Selection

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
X = df.drop('Grade',1)
y = df.Grade
X = np.array(X)
y = np.array(y)

# %%
X
# Out:
# array([[  6.6,  35. ,   1. , ...,   1. ,   0. , 254. ],
#        [  6.6,  36. ,   0. , ...,   0. ,   1. , 253. ],
#        [  8.5,  70. ,   1. , ...,   1. ,   1. , 246. ],
#        ...,
#        [  3. ,  40. ,   1. , ...,   1. ,   1. , 255. ],
#        [  6.8,  43. ,   1. , ...,   1. ,   0. , 250. ],
#        [  8.6,  55. ,   0. , ...,   1. ,   1. , 255. ]])

# %%
y
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=28)

# %%
scaler = StandardScaler()

# %%
# Implying KNN model

# %%
def KNN(x_train,y_train,x_test,y_test,scale=False,N=None,plot=True,show_knn_graph=False):
    optimal_k=N
    if N:
        print('"TO USE BEST K VALUE SET N=None"')
        model = KNeighborsClassifier(n_neighbors=N)
    else:
        score={}
        for k in range(1,30,2):
            model = KNeighborsClassifier(n_neighbors=k)
            scores = cross_val_score(model,x_train,y_train,cv=10,scoring='accuracy')
            score[scores.mean()]=k
        optimal_k=score.get(max(score.keys()))
        print('Best K value:',optimal_k)
        model = KNeighborsClassifier(n_neighbors=optimal_k)
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Model accuracy with k={} is : {}'.format(optimal_k,accuracy_score(y_test,pred)))
    cm = confusion_matrix(y_test,pred)
    
    if plot:
        plt.figure(figsize=(15,8))
        ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
        plt.show()
    else:
        print('Confusion matrix: \n',cm)
    if show_knn_graph:
        if N == None:
            xax=[]
            yax=[]
            for y,x in score.items():
                xax.append(x)
                yax.append(y)
            plt.plot(xax,yax)
            plt.title("Variation of Accuracy with K")
            plt.xlabel('K values')
            plt.ylabel('Accuracy')
            plt.grid()

# %%
KNN(x_train,y_train,x_test,y_test,N=None,plot=True,show_knn_graph=True)
# Out:
# Best K value: 7
# Model accuracy with k=7 is : 0.9874213836477987

# %%
# Implying Random Forest Classifier

# %%
def RFC(x_train,y_train,x_test,y_test,plot=True):
    model = RandomForestClassifier()
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Model Accuracy = ',accuracy_score(y_test,pred))
    cm = confusion_matrix(y_test,pred)
    if plot:
        plt.figure(figsize=(15,8))
        ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
        plt.show()
    else:
        print('Confusion matrix: \n',cm)

# %%
RFC(x_train,y_train,x_test,y_test)
# Out:
# Model Accuracy =  0.9937106918238994

# %%
# Implying XGBoost Classifier

# %%
def XGB(x_train,y_train,x_test,y_test,plot=True):
    model = XGBClassifier()
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Model Accuracy = ',accuracy_score(y_test,pred))
    cm = confusion_matrix(y_test,pred)
    if plot:
        plt.figure(figsize=(15,8))
        ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
        plt.show()
    else:
        print('Confusion matrix: \n',cm)

# %%
XGB(x_train,y_train,x_test,y_test)
# Out:
# Model Accuracy =  0.9937106918238994

# %%
# Implysing Decision Tree Classifier

# %%
def DT(x_train,y_train,x_test,y_test,plot=True):
    model = DecisionTreeClassifier()
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print('Model Accuracy = ',accuracy_score(y_test,pred))
    cm = confusion_matrix(y_test,pred)
    if plot:
        plt.figure(figsize=(15,8))
        ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
        plt.show()
    else:
        print('Confusion matrix: \n',cm)

# %%
DT(x_train,y_train,x_test,y_test)
# Out:
# Model Accuracy =  0.9905660377358491

# %% [markdown]
# ### CHECKING ACCURACY WITH SELECTED FEATURES FOR ALL MODELS

# %%
# For Random Forest Classifier

# %%
for i in range(2,8):
    x_new = SelectKBest(chi2,k=i).fit_transform(X,y)
    print('WITH {} SELECTED FEATURES\n'.format(i))
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.3)
    RFC(x_train,y_train,x_test,y_test,plot=False)
# Out:
# WITH 2 SELECTED FEATURES
#
# Model Accuracy =  0.7547169811320755
# Confusion matrix:
#  [[ 39  15  27]
#  [ 10 104  11]
#  [ 11   4  97]]
# WITH 3 SELECTED FEATURES
#
# Model Accuracy =  0.839622641509434
# Confusion matrix:
#  [[ 43   7  20]
#  [  7 112  16]
#  [  1   0 112]]
# WITH 4 SELECTED FEATURES
#
# Model Accuracy =  0.9088050314465409
# Confusion matrix:
#  [[ 68  15   5]
#  [  2 116   0]
#  [  5   2 105]]
# WITH 5 SELECTED FEATURES
#
# Model Accuracy =  0.9025157232704403
# Confusion matrix:
#  [[ 68   9   7]
#  [  6 112   0]
#  [  7   2 107]]
# WITH 6 SELECTED FEATURES
#
# Model Accuracy =  0.89937106918239
# Confusion matrix:
#  [[ 63   7   0]
#  [  7 123   0]
#  [ 18   0 100]]
# WITH 7 SELECTED FEATURES
#
# Model Accuracy =  0.9968553459119497
# Confusion matrix:
#  [[ 65   0   0]
#  [  1 124   0]
#  [  0   0 128]]

# %%
# For XGBoost

# %%
for i in range(2,8):
    x_new = SelectKBest(chi2,k=i).fit_transform(X,y)
    print('WITH {} SELECTED FEATURES\n'.format(i))
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.3)
    XGB(x_train,y_train,x_test,y_test,plot=False)
# Out:
# WITH 2 SELECTED FEATURES
#
# Model Accuracy =  0.7767295597484277
# Confusion matrix:
#  [[ 39   8  22]
#  [ 12 102  13]
#  [ 11   5 106]]
# WITH 3 SELECTED FEATURES
#
# Model Accuracy =  0.8333333333333334
# Confusion matrix:
#  [[ 42  16  22]
#  [  1 109  13]
#  [  0   1 114]]
# WITH 4 SELECTED FEATURES
#
# Model Accuracy =  0.8553459119496856
# Confusion matrix:
#  [[ 57  10   8]
#  [ 18 127   0]
#  [  9   1  88]]
# WITH 5 SELECTED FEATURES
#
# Model Accuracy =  0.89937106918239
# Confusion matrix:
#  [[ 65   9   1]
#  [ 10 112   0]
#  [ 11   1 109]]
# WITH 6 SELECTED FEATURES
#
# Model Accuracy =  0.8836477987421384
# Confusion matrix:
#  [[ 67  12   0]
#  [  7 124   0]
#  [ 16   2  90]]
# WITH 7 SELECTED FEATURES
#
# Model Accuracy =  1.0
# Confusion matrix:
#  [[ 74   0   0]
#  [  0 124   0]
#  [  0   0 120]]

# %%
# For Decision Tree Classifier

# %%
for i in range(2,8):
    x_new = SelectKBest(chi2,k=i).fit_transform(X,y)
    print('WITH {} SELECTED FEATURES\n'.format(i))
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.3)
    DT(x_train,y_train,x_test,y_test,plot=False)
# Out:
# WITH 2 SELECTED FEATURES
#
# Model Accuracy =  0.8207547169811321
# Confusion matrix:
#  [[ 36   8  17]
#  [ 11 122  15]
#  [  4   2 103]]
# WITH 3 SELECTED FEATURES
#
# Model Accuracy =  0.8050314465408805
# Confusion matrix:
#  [[ 49  13  22]
#  [  9 100  17]
#  [  1   0 107]]
# WITH 4 SELECTED FEATURES
#
# Model Accuracy =  0.8930817610062893
# Confusion matrix:
#  [[ 72   7   0]
#  [ 14 119   0]
#  [ 11   2  93]]
# WITH 5 SELECTED FEATURES
#
# Model Accuracy =  0.9056603773584906
# Confusion matrix:
#  [[ 83   7   0]
#  [  4 108   0]
#  [ 15   4  97]]
# WITH 6 SELECTED FEATURES
#
# Model Accuracy =  0.9088050314465409
# Confusion matrix:
#  [[ 53   8   5]
#  [  9 131   0]
#  [  7   0 105]]
# WITH 7 SELECTED FEATURES
#
# Model Accuracy =  1.0
# Confusion matrix:
#  [[ 69   0   0]
#  [  0 141   0]
#  [  0   0 108]]

# %%
# For KNN

# %%
for i in range(2,8):
    x_new = SelectKBest(chi2,k=i).fit_transform(X,y)
    print('WITH {} SELECTED FEATURES\n'.format(i))
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.3)
    KNN(x_train,y_train,x_test,y_test,plot=False)
# Out:
# WITH 2 SELECTED FEATURES
#
# Best K value: 15
# Model accuracy with k=15 is : 0.7547169811320755
# Confusion matrix:
#  [[ 44  10  29]
#  [ 13 107  11]
#  [ 11   4  89]]
# WITH 3 SELECTED FEATURES
#
# Best K value: 13
# Model accuracy with k=13 is : 0.7987421383647799
# Confusion matrix:
#  [[ 45  12  24]
#  [  7  97  20]
#  [  0   1 112]]
# WITH 4 SELECTED FEATURES
#
# Best K value: 3
# Model accuracy with k=3 is : 0.8553459119496856
# Confusion matrix:
#  [[ 53  23   7]
#  [  7 109   0]
#  [  0   9 110]]
# WITH 5 SELECTED FEATURES
#
# Best K value: 3
# Model accuracy with k=3 is : 0.8805031446540881
# Confusion matrix:
#  [[ 52   9  16]
#  [  1 110   6]
#  [  0   6 118]]
# WITH 6 SELECTED FEATURES
#
# Best K value: 9
# Model accuracy with k=9 is : 0.8773584905660378
# Confusion matrix:
#  [[ 54   9  18]
#  [  0 113   9]
#  [  2   1 112]]
# WITH 7 SELECTED FEATURES
#
# Best K value: 1
# Model accuracy with k=1 is : 0.9905660377358491
# Confusion matrix:
#  [[ 89   0   2]
#  [  0 123   0]
#  [  1   0 103]]

# %% [markdown]
# ### PERFORM GRIDSEARCH ON DECISION TREE

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [5, 6, 7, 8, 9],
              'criterion' :['gini', 'entropy']
             }
dt = DecisionTreeClassifier(random_state=1024)
dt_grid = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, verbose=True)
dt_grid.fit(x_train, y_train)
pred = dt_grid.predict(x_test)
print('Model Accuracy = ',accuracy_score(y_test,pred))
cm = confusion_matrix(y_test,pred)
plt.figure(figsize=(15,8))
ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
plt.show()
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Model Accuracy =  0.9968553459119497

# %% [markdown]
# ### XGBCLASSIFIER WITH GRIDSEARCH

# %%
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_xgb = GridSearchCV(
    estimator=XGBClassifier(),
    param_grid=parameters,
    scoring = 'accuracy',
    n_jobs = -1,
    cv = 10,
    verbose=True
)
grid_xgb.fit(x_train, y_train)
pred = grid_xgb.predict(x_test)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits

# %%
print('Model Accuracy = ',accuracy_score(y_test,pred))
cm = confusion_matrix(y_test,pred)
plt.figure(figsize=(15,8))
ax = sns.heatmap(cm,annot=True,linewidths=0.5,fmt=".1f")
plt.show()
# Out:
# Model Accuracy =  1.0
